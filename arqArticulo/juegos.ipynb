# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Cargar los datos del archivo Excel
file_path = "respuestas.xlsx"  # Reemplaza con la ruta de tu archivo
# Asegúrate de que el archivo tenga encabezados claros y coherentes
data = pd.read_excel(file_path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Ni de acuerdo ni en desacuerdo": 3,
    "Algo de acuerdo": 4,
    "De acuerdo": 5,
    "Totalmente de acuerdo": 6
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Renombrar las columnas con 'p1', 'p2', 'p3', etc. (suponiendo que son columnas consecutivas)
numeric_df.columns = [f"p{i+1}" for i in range(numeric_df.shape[1])]

# Calcular el promedio de acuerdo por afirmación
avg_agreement = numeric_df.mean(axis=0)

# Crear el gráfico de líneas
plt.figure(figsize=(10, 6))
plt.plot(avg_agreement.index, avg_agreement.values, marker='o', color='b')

# Configurar el gráfico
plt.title("Tendencias de acuerdo según las preguntas", fontsize=16)
plt.xlabel("Preguntas", fontsize=12)
plt.ylabel("Promedio de acuerdo", fontsize=12)
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Transponer los datos si están en formato horizontal (si es necesario)
data = df.set_index(df.columns[0]).T

# Contar la frecuencia de cada nivel de acuerdo por afirmación
response_counts = data.apply(pd.Series.value_counts).fillna(0)

# Reordenar las categorías en un orden lógico de acuerdo
categories_order = [
    "Totalmente en desacuerdo", "En desacuerdo", "Algo en desacuerdo", 
    "Ni de acuerdo ni en desacuerdo", "Algo de acuerdo", "De acuerdo", "Totalmente de acuerdo"
]
response_counts = response_counts.reindex(categories_order)

# Generar el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(12, 8))
response_counts.T.plot(kind='bar', stacked=True, ax=ax, colormap="viridis")

# Personalización del gráfico
ax.set_title("Distribución de respuestas por afirmación", fontsize=16)
ax.set_xlabel("Afirmaciones", fontsize=12)
ax.set_ylabel("Número de respuestas", fontsize=12)
ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Algo en desacuerdo": 3,
    "Ni de acuerdo ni en desacuerdo": 4,
    "Algo de acuerdo": 5,
    "De acuerdo": 6,
    "Totalmente de acuerdo": 7
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Transponer los datos si están en formato horizontal (si es necesario)
numeric_df = numeric_df.T

# Contar la frecuencia de cada nivel de acuerdo por afirmación
response_counts = numeric_df.apply(pd.Series.value_counts).fillna(0)

# Reordenar las categorías en un orden lógico de acuerdo
categories_order = [1, 2, 3, 4, 5, 6, 7]
response_counts = response_counts.reindex(categories_order)

# Mapear de nuevo los valores numéricos a las respuestas correspondientes
response_labels = {
    1: "Totalmente en desacuerdo",
    2: "En desacuerdo",
    3: "Algo en desacuerdo",
    4: "Ni de acuerdo ni en desacuerdo",
    5: "Algo de acuerdo",
    6: "De acuerdo",
    7: "Totalmente de acuerdo"
}

response_counts.index = [response_labels[i] for i in response_counts.index]

# Generar el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(12, 8))
response_counts.T.plot(kind='bar', stacked=True, ax=ax, colormap="viridis")

# Personalización del gráfico
ax.set_title("Distribución de respuestas por afirmación", fontsize=16)
ax.set_xlabel("Afirmaciones", fontsize=12)
ax.set_ylabel("Número de respuestas", fontsize=12)
ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Algo en desacuerdo": 3,
    "Ni de acuerdo ni en desacuerdo": 4,
    "Algo de acuerdo": 5,
    "De acuerdo": 6,
    "Totalmente de acuerdo": 7
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Transponer los datos para que las preguntas estén en las filas
numeric_df = numeric_df.T

# Contar la frecuencia de cada nivel de acuerdo por pregunta
response_counts = numeric_df.apply(pd.Series.value_counts).fillna(0)

# Reordenar las categorías en un orden lógico de acuerdo
categories_order = [1, 2, 3, 4, 5, 6, 7]
response_counts = response_counts.reindex(categories_order)

# Mapear de nuevo los valores numéricos a las respuestas correspondientes
response_labels = {
    1: "Totalmente en desacuerdo",
    2: "En desacuerdo",
    3: "Algo en desacuerdo",
    4: "Ni de acuerdo ni en desacuerdo",
    5: "Algo de acuerdo",
    6: "De acuerdo",
    7: "Totalmente de acuerdo"
}

response_counts.index = [response_labels[i] for i in response_counts.index]

# Generar el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(12, 8))
response_counts.T.plot(kind='bar', stacked=True, ax=ax, colormap="viridis")

# Personalización del gráfico
ax.set_title("Distribución de respuestas por pregunta", fontsize=16)
ax.set_xlabel("Preguntas", fontsize=12)
ax.set_ylabel("Número de respuestas", fontsize=12)
ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Cargar los datos del archivo Excel
file_path = "respuestas.xlsx"  # Reemplaza con la ruta de tu archivo
# Asegúrate de que el archivo tenga encabezados claros y coherentes
data = pd.read_excel(file_path)
df = data
df.head()
# Out:
#   A veces pierdo la noción del tiempo mientras juego.   \
# 0                                 Algo en desacuerdo
# 1                                                NaN
# 2                                         De acuerdo
# 3                     Ni de acuerdo ni en desacuerdo
# 4                                         De acuerdo
#
#   Disfruto de los efectos de sonido del juego.   \
# 0                Ni de acuerdo ni en desacuerdo
# 1                               Algo de acuerdo
# 2                         Totalmente de acuerdo
# 3                Ni de acuerdo ni en desacuerdo
# 4                                    De acuerdo
#
#   Creo que es fácil aprender a jugar.                Disfruto jugando   \
# 0                      Algo de acuerdo                             NaN
# 1                        En desacuerdo              Algo en desacuerdo
# 2                           De acuerdo           Totalmente de acuerdo
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Algo en desacuerdo": 3,
    "Ni de acuerdo ni en desacuerdo": 4,
    "Algo de acuerdo": 5,
    "De acuerdo": 6,
    "Totalmente de acuerdo": 7
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Contar la frecuencia de cada nivel de acuerdo por afirmación
response_counts = numeric_df.apply(pd.Series.value_counts).fillna(0)

# Reordenar las categorías en un orden lógico de acuerdo
categories_order = [1, 2, 3, 4, 5, 6, 7]
response_counts = response_counts.reindex(categories_order)

# Mapear de nuevo los valores numéricos a las respuestas correspondientes
response_labels = {
    1: "Totalmente en desacuerdo",
    2: "En desacuerdo",
    3: "Algo en desacuerdo",
    4: "Ni de acuerdo ni en desacuerdo",
    5: "Algo de acuerdo",
    6: "De acuerdo",
    7: "Totalmente de acuerdo"
}

# Asignar las etiquetas correspondientes a las categorías
response_counts.index = [response_labels[i] for i in response_counts.index]

# Generar el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(12, 8))
response_counts.T.plot(kind='bar', stacked=True, ax=ax, colormap="viridis")

# Personalización del gráfico
ax.set_title("Distribución de respuestas por afirmación", fontsize=16)
ax.set_xlabel("Afirmaciones", fontsize=12)
ax.set_ylabel("Número de respuestas", fontsize=12)
ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Algo en desacuerdo": 3,
    "Ni de acuerdo ni en desacuerdo": 4,
    "Algo de acuerdo": 5,
    "De acuerdo": 6,
    "Totalmente de acuerdo": 7
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Contar la frecuencia de cada nivel de acuerdo por afirmación
response_counts = numeric_df.apply(pd.Series.value_counts).fillna(0)

# Reordenar las categorías en un orden lógico de acuerdo
categories_order = [1, 2, 3, 4, 5, 6, 7]
response_counts = response_counts.reindex(categories_order)

# Mapear de nuevo los valores numéricos a las respuestas correspondientes
response_labels = {
    1: "Totalmente en desacuerdo",
    2: "En desacuerdo",
    3: "Algo en desacuerdo",
    4: "Ni de acuerdo ni en desacuerdo",
    5: "Algo de acuerdo",
    6: "De acuerdo",
    7: "Totalmente de acuerdo"
}

# Asignar las etiquetas correspondientes a las categorías
response_counts.index = [response_labels[i] for i in response_counts.index]

# Abreviar las preguntas para la visualización en el gráfico (se pueden acortar según se necesite)
shortened_questions = [
    "Pierdo noción de tiempo",
    "Efectos de sonido",
    "Fácil de aprender",
    "Disfruto jugando",
    "Suspenso sobre éxito",
    "Juego con otros",
    "Gráficos adaptativos",
    "Éxito superando obstáculos",
    "Juego único y original",
    "Juego divertido",
    "Aburrimiento mientras juego",
    "Exploración dentro del juego",
    "No me canso mientras juego",
    "Menús fáciles de usar",
    "Volvería a jugarlo",
    "Interacción social",
    "Separación del mundo exterior",
    "Curiosidad estimulada",
    "Audio mejora la experiencia",
    "Bloqueo de distracciones"
]

# Generar el gráfico de barras apiladas
fig, ax = plt.subplots(figsize=(12, 8))
response_counts.T.plot(kind='bar', stacked=True, ax=ax, colormap="viridis")

# Personalización del gráfico
ax.set_title("Distribución de respuestas por afirmación", fontsize=16)
ax.set_xlabel("Afirmaciones", fontsize=12)
ax.set_ylabel("Número de respuestas", fontsize=12)
ax.set_xticklabels(shortened_questions, rotation=45, ha='right')  # Usar las preguntas abreviadas
ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')

# Ajustar el gráfico
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 75
#      73 ax.set_xlabel("Afirmaciones", fontsize=12)
#      74 ax.set_ylabel("Número de respuestas", fontsize=12)
# ---> 75 ax.set_xticklabels(shortened_questions, rotation=45, ha='right')  # Usar las preguntas abreviadas
#      76 ax.legend(title="Nivel de acuerdo", bbox_to_anchor=(1.05, 1), loc='upper left')
#      78 # Ajustar el gráfico
#
# File d:\tesis\11virtenv\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File d:\tesis\11virtenv\Lib\site-packages\matplotlib\axis.py:2071, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2067 elif isinstance(locator, mticker.FixedLocator):
# ...

# %%
# Cargar los datos del archivo Excel
file_path = "respuestas.xlsx"  # Reemplaza con la ruta de tu archivo
# Asegúrate de que el archivo tenga encabezados claros y coherentes
data = pd.read_excel(file_path)
df = data
df.head()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Conversión de respuestas cualitativas a valores numéricos
# Define un diccionario para mapear las respuestas a valores numéricos
mapeo_respuestas = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Algo en desacuerdo": 3,
    "Ni de acuerdo ni en desacuerdo": 4,
    "Algo de acuerdo": 5,
    "De acuerdo": 6,
    "Totalmente de acuerdo": 7,

}

# %%
# Aplicar el mapeo
df_numerico = df.copy()
df_numerico.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: mapeo_respuestas.get(x, None))

# Asegurarse de que los datos sean numéricos
df_numerico.iloc[:, 1:] = df_numerico.iloc[:, 1:].apply(pd.to_numeric, errors="coerce")

# Manejar valores faltantes (opcional: usar promedio)
df_numerico.fillna(df_numerico.mean(), inplace=True)

# Calcular el promedio por afirmación
df_numerico["Promedio"] = df_numerico.iloc[:, 1:].mean(axis=1)

# Preparar el mapa de calor
plt.figure(figsize=(12, 8))
ax = sns.heatmap(
    df_numerico.iloc[:, 1:-1].T,  # Transponer para que las afirmaciones estén en el eje vertical
    cmap="coolwarm",
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"label": "Nivel promedio de acuerdo"}
)

# Configurar etiquetas y título
plt.title("Mapa de Calor: Nivel de Acuerdo Promedio por Afirmación", fontsize=14)
plt.xlabel("Afirmaciones", fontsize=12)
plt.ylabel("Niveles de Acuerdo", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 9
#       6 df_numerico.iloc[:, 1:] = df_numerico.iloc[:, 1:].apply(pd.to_numeric, errors="coerce")
#       8 # Manejar valores faltantes (opcional: usar promedio)
# ----> 9 df_numerico.fillna(df_numerico.mean(), inplace=True)
#      11 # Calcular el promedio por afirmación
#      12 df_numerico["Promedio"] = df_numerico.iloc[:, 1:].mean(axis=1)
#
# File d:\tesis\11virtenv\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# ...

# %%
# Cargar los datos del archivo Excel
file_path = "respuestas.xlsx"  # Reemplaza con la ruta de tu archivo
# Asegúrate de que el archivo tenga encabezados claros y coherentes
data = pd.read_excel(file_path)
df = data
df.head()
# Out:
#   A veces pierdo la noción del tiempo mientras juego.   \
# 0                                 Algo en desacuerdo
# 1                                                NaN
# 2                                         De acuerdo
# 3                     Ni de acuerdo ni en desacuerdo
# 4                                         De acuerdo
#
#   Disfruto de los efectos de sonido del juego.   \
# 0                Ni de acuerdo ni en desacuerdo
# 1                               Algo de acuerdo
# 2                         Totalmente de acuerdo
# 3                Ni de acuerdo ni en desacuerdo
# 4                                    De acuerdo
#
#   Creo que es fácil aprender a jugar.                Disfruto jugando   \
# 0                      Algo de acuerdo                             NaN
# 1                        En desacuerdo              Algo en desacuerdo
# 2                           De acuerdo           Totalmente de acuerdo
# ...

# %%
# Convertir respuestas categóricas a valores numéricos
df_numeric = df.replace(mapeo_respuestas)

# Seleccionar las afirmaciones relacionadas para el gráfico de dispersión
x_label = "Disfruto de los gráficos del juego"
y_label = "Creo que los gráficos se adaptan al estilo del juego"
x = df_numeric[x_label]
y = df_numeric[y_label]

# Crear gráfico de dispersión
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, s=100, color="blue", alpha=0.7)

# Configurar etiquetas y título
plt.title("Comparación de Afirmaciones Relacionadas", fontsize=16)
plt.xlabel(x_label, fontsize=12)
plt.ylabel(y_label, fontsize=12)
plt.grid(True)
plt.tight_layout()

# Mostrar gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\tesis\11virtenv\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File d:\tesis\11virtenv\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\tesis\11virtenv\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Disfruto de los gráficos del juego'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(df.columns)
# Out:
# Index(['A veces pierdo la noción del tiempo mientras juego. ',
#        'Disfruto de los efectos de sonido del juego. ',
#        'Creo que es fácil aprender a jugar. ', 'Disfruto jugando ',
#        'Estoy en suspenso sobre si tendré éxito en el juego. ',
#        'Puedo jugar el juego con otros jugadores si así lo deseo. ',
#        'Creo que los gráficos del juego se adaptan al estado de ánimo o al estilo del juego.',
#        'Me siento exitoso cuando supero los obstáculos en el juego. ',
#        '¿Qué tan de acuerdo estás con la afirmación: 'Creo que el juego es único u original'?',
#        '¿Qué tan de acuerdo estás con la afirmación: 'Creo que el juego es divertido'?',
#        '¿Qué tan de acuerdo estás con la afirmación: 'Siempre sé cómo lograr mis objetivos en el juego'?',
#        '¿Qué tan de acuerdo estás con la afirmación: 'Encuentro que los controles del juego son sencillos'?',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Diccionario de mapeo de respuestas a valores numéricos
response_map = {
    "Totalmente en desacuerdo": 1,
    "En desacuerdo": 2,
    "Ni de acuerdo ni en desacuerdo": 3,
    "Algo de acuerdo": 4,
    "De acuerdo": 5,
    "Totalmente de acuerdo": 6
}

# Definir las categorías y las afirmaciones que pertenecen a cada una
categories = {
    "Gráficos": [
        "Creo que los gráficos del juego se adaptan al estado de ánimo o al estilo del juego."
    ],
    "Audio": [
        "Siento que el audio del juego (por ejemplo, efectos de sonido, música) mejora mi experiencia de juego."
    ],
    "Interacción Social": [
        "Disfruto de la interacción social dentro del juego."
    ],
    "Controles": [
        "Considero que los menús del juego son fáciles de usar."
    ],
    "Inmersión": [
        "Me siento separado del mundo exterior mientras juego."
    ]
}

# Función para convertir las respuestas en valores numéricos
def convert_responses(df):
    return df.applymap(lambda x: response_map.get(x, None))

# Convertir las respuestas en valores numéricos
numeric_df = convert_responses(df)

# Calcular el promedio por categoría
category_averages = {}
for category, questions in categories.items():
    category_columns = [col for col in numeric_df.columns if any(q in col for q in questions)]
    category_averages[category] = numeric_df[category_columns].mean(axis=1).mean()

# Crear el gráfico de líneas
plt.figure(figsize=(10, 6))
plt.plot(list(category_averages.keys()), list(category_averages.values()), marker='o', color='b')

# Configurar el gráfico
plt.title("Tendencias de acuerdo según categorías de juego")
plt.xlabel("Categorías")
plt.ylabel("Promedio de acuerdo")
plt.grid(True)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
